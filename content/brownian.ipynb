# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
W = np.array([0.0])

# %%
W
# Out:
# array([0.])

# %%
for i in range(1000):
    W = np.append(W, np.max([0.0, W[-1] + np.random.normal(0, 1)]))

# %%
W
# Out:
# array([ 0.        ,  0.        ,  0.        , ..., 63.05534588,
#        62.3050014 , 62.5974929 ])

# %%
plt.plot(W)
